# %%
import pandas as pd

import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.label_tools import plot_stream, mark

# %% [markdown]
# # Two Classes Labeling: sprint: yes | no

# %%
labels_df = pd.DataFrame(columns=["path", "start", "end"]).set_index("path")

# %% [markdown]
# ## 16th of July Datasets

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784073260195.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 8100, 37000)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784073733285.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5200, 30200)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784074091744.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5100, 28900)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784074618971.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5300, 27800)

# %% [markdown]
# ## 19th of July Datasets

# %%
relative_path = "data/19_07_2026/session_num_1784417040372.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5700, 22000)

# %%
relative_path = "data/19_07_2026/session_num_1784417306824.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 4100, 26000)

# %%
relative_path = "data/19_07_2026/session_num_1784418025429.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 7000, 27200)

# %% [markdown]
# ## 29th of July Datasets

# %%
relative_path = "data/29_7_2026/session_num_1785333949070.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5100, 30000)

# %%
relative_path = "data/29_7_2026/session_num_1785334650288.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 9300, 34500)

# %%
relative_path = "data/29_7_2026/session_num_1785335981969.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5500, 22900)

# %%
relative_path = "data/29_7_2026/session_num_1785336652647.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 6700, 29100)

# %% [markdown]
# ## 6th of August Datasets

# %%
relative_path = "data/6_8_2026/faulty_num_1785989529966.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 7100, 28000)

# %%
relative_path = "data/6_8_2026/faulty2_num_1785990267949.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 4100, 23000)

# %%
relative_path = "data/6_8_2026/inaccurate_num_1785988999439.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 8800, 33100)

# %%
relative_path = "data/6_8_2026/session_num_1785990974746.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 7900, 27500)

# %%
relative_path = "data/6_8_2026/session_num_1785991492241.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 6800, 30000)

# %% [markdown]
# ## Save to CSV

# %%
labels_df.reset_index().to_csv("../data/labels/sprint_start_end.csv", index=False)

# %% [markdown]
# # Multi classes Sprint Phases Labeling: sprint: no | accel | cruise | decel

# %%
labels_df = pd.DataFrame(columns=["path", "start", "cruise", "decel", "end"]).set_index(
    "path"
)

# %% [markdown]
# ## 16th of July Datasets

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784073260195.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=False, loc= 27000, scale=15000)
mark(path, labels_df, ax, 8100, 12000, 29000, 37000)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784073733285.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5200, 8300, 21000,  30200)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784074091744.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5100, 8100, 20100, 28900)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784074618971.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5300, 7600, 20400, 27800)

# %% [markdown]
# ## 19th of July Datasets

# %%
relative_path = "data/19_07_2026/session_num_1784417040372.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5700, 8700, 15400, 22000)

# %%
relative_path = "data/19_07_2026/session_num_1784417306824.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 4100, 7900, 16600, 26000)

# %%
relative_path = "data/19_07_2026/session_num_1784418025429.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 7000, 10000, 20500, 27200)

# %% [markdown]
# ## 29th of July Datasets

# %%
relative_path = "data/29_7_2026/session_num_1785333949070.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5100, 8100, 21000, 30000)

# %%
relative_path = "data/29_7_2026/session_num_1785334650288.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 9300, 12300, 27500, 34500)

# %%
relative_path = "data/29_7_2026/session_num_1785335981969.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 5500, 8000, 15700, 22900)

# %%
relative_path = "data/29_7_2026/session_num_1785336652647.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 6700, 10200, 21600, 29100)

# %% [markdown]
# ## 6th of August Datasets

# %%
relative_path = "data/6_8_2026/faulty_num_1785989529966.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 7100, 9500, 19500, 28000)

# %%
relative_path = "data/6_8_2026/faulty2_num_1785990267949.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 4100, 7800, 14900, 23000)

# %%
relative_path = "data/6_8_2026/inaccurate_num_1785988999439.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 8800, 11600, 23000, 33100)

# %%
relative_path = "data/6_8_2026/session_num_1785990974746.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 7900, 12400, 19000, 27500)

# %%
relative_path = "data/6_8_2026/session_num_1785991492241.csv"
path = "../" + relative_path
ax = plot_stream(path)
mark(path, labels_df, ax, 6800, 10900, 18100, 30000)

# %% [markdown]
# ## Save to CSV

# %%
labels_df.reset_index().to_csv("../data/labels/sprint_start_cruise_decel_end_v1.csv", index=False)

# %% [markdown]
# # Binary classes Effort Labeling: intense: yes | no

# %%
labels_df = pd.DataFrame(columns=["path", "start", "end"]).set_index(
    "path"
)

# %% [markdown]
# ## 16th of July Datasets

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784073260195.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 32000, scale=10000)
mark(path, labels_df, ax, 8100, 29000)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784073733285.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 23000, scale=10000)
mark(path, labels_df, ax, 5200, 22200)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784074091744.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 20100, scale=10000)
mark(path, labels_df, ax, 5100, 20600)

# %%
relative_path = "data/16_7_2026/stationary_sprint_walk_1784074618971.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 20400, scale=10000)
mark(path, labels_df, ax, 5300, 20400)

# %% [markdown]
# ## 19th of July Datasets

# %%
relative_path = "data/19_07_2026/session_num_1784417040372.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 15400, scale=8000)
mark(path, labels_df, ax, 5700, 16500)

# %%
relative_path = "data/19_07_2026/session_num_1784417306824.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 15400, scale=8000)
mark(path, labels_df, ax, 4100, 17600)

# %%
relative_path = "data/19_07_2026/session_num_1784418025429.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 19400, scale=8000)
mark(path, labels_df, ax, 7000, 20200)

# %% [markdown]
# ## 29th of July Datasets

# %%
relative_path = "data/29_7_2026/session_num_1785333949070.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 22000, scale=8000)
mark(path, labels_df, ax, 5100, 21500)

# %%
relative_path = "data/29_7_2026/session_num_1785334650288.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 29000, scale=8000)
mark(path, labels_df, ax, 9300, 27200)

# %%
relative_path = "data/29_7_2026/session_num_1785335981969.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 16000, scale=8000)
mark(path, labels_df, ax, 5500, 17200)

# %%
relative_path = "data/29_7_2026/session_num_1785336652647.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 22000, scale=8000)
mark(path, labels_df, ax, 6700, 23400)

# %% [markdown]
# ## 6th of August Datasets

# %%
relative_path = "data/6_8_2026/faulty_num_1785989529966.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 20000, scale=8000)
mark(path, labels_df, ax, 7100, 21100)

# %%
relative_path = "data/6_8_2026/faulty2_num_1785990267949.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 16000, scale=8000)
mark(path, labels_df, ax, 4100, 16600)

# %%
relative_path = "data/6_8_2026/inaccurate_num_1785988999439.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 23000, scale=8000)
mark(path, labels_df, ax, 8800, 24500)

# %%
relative_path = "data/6_8_2026/session_num_1785990974746.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 19000, scale=8000)
mark(path, labels_df, ax, 7900, 19000)

# %%
relative_path = "data/6_8_2026/session_num_1785991492241.csv"
path = "../" + relative_path
ax = plot_stream(path, zoom=True, loc= 19000, scale=8000)
mark(path, labels_df, ax, 6800, 19800)

# %% [markdown]
# ## Save to CSV

# %%
labels_df.reset_index().to_csv("../data/labels/intense_start_end_v1.csv", index=False)
